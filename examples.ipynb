# %%
from magma_mounts import MountsProject

# %%
mounts_project = MountsProject()

# %%
mounts_project.volcanoes
# Out:
# [{'name': 'Lewotobi Laki-laki', 'code': 264180},
#  {'name': 'Marapi', 'code': 261140}]

# %%
mounts_project.run()
# Out:
# 🌋 Extracting Lewotobi Laki-laki volcano.
# 🗃️ Saved to: D:\Projects\extract-mounts\output\json\264180.json
# => ✅ Excel: D:\Projects\extract-mounts\output\excel\so2\Lewotobi Laki-laki.xlsx
# => ✅ CSV: D:\Projects\extract-mounts\output\csv\so2\Lewotobi Laki-laki.csv
# => ✅ Excel: D:\Projects\extract-mounts\output\excel\thermal\Lewotobi Laki-laki.xlsx
# => ✅ CSV: D:\Projects\extract-mounts\output\csv\thermal\Lewotobi Laki-laki.csv
# 🌋 Extracting Marapi volcano.
# 🗃️ Saved to: D:\Projects\extract-mounts\output\json\261140.json
# => ✅ Excel: D:\Projects\extract-mounts\output\excel\so2\Marapi.xlsx
# => ✅ CSV: D:\Projects\extract-mounts\output\csv\so2\Marapi.csv
# => ✅ Excel: D:\Projects\extract-mounts\output\excel\thermal\Marapi.xlsx
# => ✅ CSV: D:\Projects\extract-mounts\output\csv\thermal\Marapi.csv
